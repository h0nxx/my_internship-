# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
url = "https://raw.githubusercontent.com/AdiPersonalWorks/Random/master/student_scores%20-%20student_scores.csv"
df = pd.read_csv(url)

print(df.head())
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
print(df.isnull())
# Out:
#     Hours  Scores
# 0   False   False
# 1   False   False
# 2   False   False
# 3   False   False
# 4   False   False
# 5   False   False
# 6   False   False
# 7   False   False
# 8   False   False
# 9   False   False
# 10  False   False
# 11  False   False
# 12  False   False
# 13  False   False
# 14  False   False
# 15  False   False
# 16  False   False
# 17  False   False
# 18  False   False
# 19  False   False
# 20  False   False
# 21  False   False
# 22  False   False
# 23  False   False
# 24  False   False

# %%
print(df.isnull().sum())

plt.scatter(df["Hours"],df['Scores'],color='blue')
plt.title('Hours vs Scores')
plt.xlabel('Hours Studied')
plt.ylabel('Score')
plt.grid()
plt.show
# Out:
# Hours     0
# Scores    0
# dtype: int64
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x = df[['Hours']]
y = df['Scores']

x_train,X_train,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x = df[['Hours']]
y = df['Scores']


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)


model = LinearRegression()
model.fit(x_train, y_train)


y_pred = model.predict(x_test)

df_pred = pd.DataFrame({'Actual': y_test, 'predicted': y_pred})
print(df_pred)
# Out:
#     Actual  predicted
# 8       81  83.188141
# 16      30  27.032088
# 0       21  27.032088
# 23      76  69.633232
# 11      62  59.951153

# %%
mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)

print(f'Mean Squared Error:',mse)
print(f'R-squared Error:',(r2))
# Out:
# Mean Squared Error: 18.943211722315272
# R-squared Error: 0.9678055545167994

# %%
plt.scatter(x,y,color='green')
plt.plot(x,model.predict(x),color='red')
plt.title('Linear Regression Fit')
plt.xlabel('Hours Studied')
plt.ylabel('Scores')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
hours = np.array([[8.25]])
predicted_score = model.predict(hours)
print(f'predicted score for 8.25 study hours:{predicted_score[0]:.2f}')
# Out:
# predicted score for 8.25 study hours:82.70
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
